# %% [markdown]
# ## Tutorial 02: Preprocessing and Building Terra MODIS, Landsat8, and Sentinel-2 Triples
#
# In this tutorial, we will prepare the data downloaded in Tutorial 01 to create clean and aligned image triples (Terra MODIS, Landsat, Sentinel-2) for spatio-temporal fusion tasks.
#
# We will:
# - Load Terra MODIS, Landsat 8, and Sentinel-2 image collections matched on common dates.
# - Apply progressive focal mean interpolation to fill missing values due to clouds or technical issues.
# - Spatially align Terra MODIS images the Sentinel-2 resolution.
# - Save the resulting triples in a structured format.
#
#
# These processed triples can then be used to train and evaluate models such as WGAST or any custom deep learning architecture for spatio-temporal fusion of land surface temperature tasks.

# %%
import sys
import os
sys.path.append(os.path.abspath('..'))  # go up to root directory

from data_preparation.GetTriple import GetTriple
from data_preparation.DataProcessor import DataProcessor
import numpy as np
import time
import pandas as pd
from datetime import datetime

# %%
city = "Orleans"   

a = np.load(f'common_dates_t1_{city}.npy')
print(len(a), a[:5] if len(a) else 'EMPTY')
# Out:
# 10 ['2018-02-23' '2018-10-21' '2019-09-06' '2020-07-22' '2022-03-06']

# %% [markdown]
# ## Step 01 : Load the Data for Triple Construction

# %%
# Initialize the triple preparation helper
get_triple = GetTriple()

# Load the common dates shared across all three satellite sources
common_dates_array = np.load(f'common_dates_t1_{city}.npy')

# Load Sentinel-2 images that match the common dates
sentinel2_images = get_triple.load_sentinel(
    f'data/wgast/raw/Sentinel2_{city}',
    common_dates_array
)

# Load Landsat 8 images that match the common dates
landsat_images = get_triple.load_landsat(
    f'data/wgast/raw/Landsat8_{city}',
    common_dates_array
)

# Load MODIS images that match the common dates
modis_images = get_triple.load_modis(
    f'data/wgast/raw/MODIS_{city}',
    common_dates_array
)
# Out:
# Reading Sentinel file: data/wgast/raw/Sentinel2_Orleans/20180223T110041_20180223T110631_T31UDP.tif
# Reading Sentinel file: data/wgast/raw/Sentinel2_Orleans/20181021T110101_20181021T110649_T31UDP.tif
# Reading Sentinel file: data/wgast/raw/Sentinel2_Orleans/20190906T105621_20190906T110527_T31UDP.tif
# Reading Sentinel file: data/wgast/raw/Sentinel2_Orleans/20200722T105631_20200722T110027_T31UDP.tif
# Reading Sentinel file: data/wgast/raw/Sentinel2_Orleans/20220306T104819_20220306T105455_T31UDP.tif
# Reading Sentinel file: data/wgast/raw/Sentinel2_Orleans/20220813T104629_20220813T104623_T31UDP.tif
# Reading Sentinel file: data/wgast/raw/Sentinel2_Orleans/20230528T105621_20230528T105909_T31UDP.tif
# Reading Sentinel file: data/wgast/raw/Sentinel2_Orleans/20240412T105621_20240412T110532_T31UDP.tif
# Reading Sentinel file: data/wgast/raw/Sentinel2_Orleans/20240919T105731_20240919T110558_T31UDP.tif
# Reading Sentinel file: data/wgast/raw/Sentinel2_Orleans/20241021T105009_20241021T105637_T31UDP.tif
# Reading Landsat file: data/wgast/raw/Landsat8_Orleans/LC08_199027_20180223.tif
# Reading Landsat file: data/wgast/raw/Landsat8_Orleans/LC08_199027_20181021.tif
# Reading Landsat file: data/wgast/raw/Landsat8_Orleans/LC08_199027_20190906.tif
# Reading Landsat file: data/wgast/raw/Landsat8_Orleans/LC08_199027_20200722.tif
# Reading Landsat file: data/wgast/raw/Landsat8_Orleans/LC08_199027_20220306.tif
# Reading Landsat file: data/wgast/raw/Landsat8_Orleans/LC08_199027_20220813.tif
# Reading Landsat file: data/wgast/raw/Landsat8_Orleans/LC08_199027_20230528.tif
# Reading Landsat file: data/wgast/raw/Landsat8_Orleans/LC08_199027_20240412.tif
# Reading Landsat file: data/wgast/raw/Landsat8_Orleans/LC08_199027_20240919.tif
# Reading Landsat file: data/wgast/raw/Landsat8_Orleans/LC08_199027_20241021.tif
# Reading MODIS file: data/wgast/raw/MODIS_Orleans/2018_02_23.tif
# Reading MODIS file: data/wgast/raw/MODIS_Orleans/2018_10_21.tif
# Reading MODIS file: data/wgast/raw/MODIS_Orleans/2019_09_06.tif
# Reading MODIS file: data/wgast/raw/MODIS_Orleans/2020_07_22.tif
# Reading MODIS file: data/wgast/raw/MODIS_Orleans/2022_03_06.tif
# Reading MODIS file: data/wgast/raw/MODIS_Orleans/2022_08_13.tif
# Reading MODIS file: data/wgast/raw/MODIS_Orleans/2023_05_28.tif
# Reading MODIS file: data/wgast/raw/MODIS_Orleans/2024_04_12.tif
# Reading MODIS file: data/wgast/raw/MODIS_Orleans/2024_09_19.tif
# Reading MODIS file: data/wgast/raw/MODIS_Orleans/2024_10_21.tif

# %% [markdown]
# ## Step 02 : Spatial Interpolation

# %%
# Initialize the data processor
data_processor = DataProcessor()

# Get target resolution dimensions from Sentinel-2 (highest resolution: 10 m)
height, width = sentinel2_images[0][0][0].shape

# (Optional) Get original Landsat resolution (30 m)
height2, width2 = landsat_images[0][0][0].shape

# --- Interpolation for Terra MODIS Images ---
# Apply progressive focal mean to fill missing values, then upscale to Sentinel-2 resolution
start_time = time.time()
modis_preprocessed = data_processor.progressive_focal_mean(modis_images)
modis_images_interpolated = data_processor.resize_modis_images(modis_preprocessed, height, width)
end_time = time.time()
print(f"Terra MODIS interpolation took {end_time - start_time:.2f} seconds.")


# --- Interpolation for Landsat Images ---
# Apply multiband progressive focal mean 
start_time = time.time()

landsat_proprocessed = data_processor.progressive_focal_mean_multiband(
    landsat_images, initial_size=5, step_size=5
)

end_time = time.time()
print(f"Landsat 8 interpolation took {end_time - start_time:.2f} seconds.")

# --- Interpolation for Sentinel-2 Images ---
# Sentinel-2 is already high resolution
start_time = time.time()

sentinel2_proprocessed = data_processor.progressive_focal_mean_multiband(
    sentinel2_images, initial_size=15, step_size=15
)

end_time = time.time()
print(f"Sentinel 2 interpolation took {end_time - start_time:.2f} seconds.")
# Out:
# Image number :  1  has been filled
# Image number :  2  has been filled
# Image number :  3  has been filled
# Image number :  4  has been filled
# Image number :  5  has been filled
# Image number :  6  has been filled
# Image number :  7  has been filled
# Image number :  8  has been filled
# Image number :  9  has been filled
# Image number :  10  has been filled
# Terra MODIS interpolation took 0.07 seconds.
# Image number: 1 has been filled
# Image number: 2 has been filled
# Image number: 3 has been filled
# Image number: 4 has been filled
# Image number: 5 has been filled
# Image number: 6 has been filled
# Image number: 7 has been filled
# Image number: 8 has been filled
# Image number: 9 has been filled
# Image number: 10 has been filled
# Landsat 8 interpolation took 29.22 seconds.
# Image number: 1 has been filled
# Image number: 2 has been filled
# Image number: 3 has been filled
# Image number: 4 has been filled
# Image number: 5 has been filled
# Image number: 6 has been filled
# Image number: 7 has been filled
# Image number: 8 has been filled
# Image number: 9 has been filled
# Image number: 10 has been filled
# Sentinel 2 interpolation took 219.74 seconds.

# %% [markdown]
# ## Step 03 : Save the Triples

# %%
import os
from datetime import datetime

# Parse the dates from string to datetime objects
dates = [datetime.strptime(date, "%Y-%m-%d") for date in common_dates_array]

# Per-city output folder so a second city doesn't overwrite the first
out_dir = f"data/wgast/Triple/{city}"
os.makedirs(out_dir, exist_ok=True)  # Create the folder if it doesn't exist

# Save the preprocessed Terra MODIS, Landsat 8, and Sentinel-2 images
get_triple.save_modis_formatted(modis_images_interpolated, dates, out_dir)
get_triple.save_landsat_formatted(landsat_proprocessed, dates, out_dir)
get_triple.save_sentinel_formatted(sentinel2_proprocessed, dates, out_dir)
