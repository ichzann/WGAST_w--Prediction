# %% [markdown]
# ## Tutorial 02: Preprocessing and Building Terra MODIS, Landsat8, and Sentinel-2 Triples
#
# In this tutorial, we will prepare the data downloaded in Tutorial 01 to create clean and aligned image triples (Terra MODIS, Landsat, Sentinel-2) for spatio-temporal fusion tasks.
#
# We will:
# - Load Terra MODIS, Landsat 8, and Sentinel-2 image collections matched on common dates.
# - Apply progressive focal mean interpolation to fill missing values due to clouds or technical issues.
# - Spatially align Terra MODIS images the Sentinel-2 resolution.
# - Save the resulting triples in a structured format.
#
#
# These processed triples can then be used to train and evaluate models such as WGAST or any custom deep learning architecture for spatio-temporal fusion of land surface temperature tasks.

# %%
import sys
import os
sys.path.append(os.path.abspath('..'))  # go up to root directory

from data_preparation.GetTriple import GetTriple
from data_preparation.DataProcessor import DataProcessor
import numpy as np
import time
import pandas as pd
from datetime import datetime

# %%
a = np.load('common_dates_t1_Istanbul.npy')
print(len(a), a[:5] if len(a) else 'EMPTY')
# Out:
# 27 ['2017-06-07' '2018-11-01' '2019-05-28' '2019-09-17' '2019-12-06']

# %% [markdown]
# ## Step 01 : Load the Data for Triple Construction

# %%
# Initialize the triple preparation helper
get_triple = GetTriple()

city = "_"+"Istanbul"

# Load the common dates shared across all three satellite sources
common_dates_array = np.load(f'common_dates_t1{city}.npy')

# Load Sentinel-2 images that match the common dates
sentinel2_images = get_triple.load_sentinel(
    f'data/raw/Sentinel2{city}',
    common_dates_array
)

# Load Landsat 8 images that match the common dates
landsat_images = get_triple.load_landsat(
    f'data/raw/Landsat8{city}',
    common_dates_array
)

# Load MODIS images that match the common dates
modis_images = get_triple.load_modis(
    f'data/raw/MODIS{city}',
    common_dates_array
)
# Out:
# Reading Sentinel file: data/raw/Sentinel2_Istanbul/20170607T090019_20170607T090017_T35TPF.tif
# Reading Sentinel file: data/raw/Sentinel2_Istanbul/20181101T085111_20181101T085225_T35TPF.tif
# Reading Sentinel file: data/raw/Sentinel2_Istanbul/20190528T085609_20190528T090656_T35TPF.tif
# Reading Sentinel file: data/raw/Sentinel2_Istanbul/20190917T084611_20190917T084930_T35TPF.tif
# Reading Sentinel file: data/raw/Sentinel2_Istanbul/20191206T085341_20191206T085335_T35TPF.tif
# Reading Sentinel file: data/raw/Sentinel2_Istanbul/20200412T085549_20200412T090029_T35TPF.tif
# Reading Sentinel file: data/raw/Sentinel2_Istanbul/20200701T085559_20200701T085944_T35TPF.tif
# Reading Sentinel file: data/raw/Sentinel2_Istanbul/20200802T084601_20200802T085244_T35TPF.tif
# Reading Sentinel file: data/raw/Sentinel2_Istanbul/20210226T085829_20210226T090307_T35TPF.tif
# Reading Sentinel file: data/raw/Sentinel2_Istanbul/20210517T085559_20210517T085905_T35TPF.tif
# Reading Sentinel file: data/raw/Sentinel2_Istanbul/20210805T085559_20210805T090150_T35TPF.tif
# Reading Sentinel file: data/raw/Sentinel2_Istanbul/20220402T085549_20220402T090131_T35TPF.tif
# Reading Sentinel file: data/raw/Sentinel2_Istanbul/20220723T084611_20220723T085405_T35TPF.tif
# Reading Sentinel file: data/raw/Sentinel2_Istanbul/20220909T085559_20220909T085847_T35TPF.tif
# Reading Sentinel file: data/raw/Sentinel2_Istanbul/20221230T085351_20221230T085750_T35TPF.tif
# Reading Sentinel file: data/raw/Sentinel2_Istanbul/20230726T085559_20230726T090234_T35TPF.tif
# Reading Sentinel file: data/raw/Sentinel2_Istanbul/20231014T085829_20231014T090730_T35TPF.tif
# Reading Sentinel file: data/raw/Sentinel2_Istanbul/20240610T085559_20240610T090231_T35TPF.tif
# Reading Sentinel file: data/raw/Sentinel2_Istanbul/20240829T085559_20240829T090223_T35TPF.tif
# Reading Sentinel file: data/raw/Sentinel2_Istanbul/20241219T085401_20241219T085357_T35TPF.tif
# Reading Sentinel file: data/raw/Sentinel2_Istanbul/20250309T084831_20250309T085502_T35TPF.tif
# Reading Sentinel file: data/raw/Sentinel2_Istanbul/20250410T085431_20250410T085431_T35TPF.tif
# Reading Sentinel file: data/raw/Sentinel2_Istanbul/20250528T084621_20250528T085505_T35TPF.tif
# Reading Sentinel file: data/raw/Sentinel2_Istanbul/20250715T085559_20250715T090231_T35TPF.tif
# Reading Sentinel file: data/raw/Sentinel2_Istanbul/20250816T084621_20250816T085913_T35TPF.tif
# Reading Sentinel file: data/raw/Sentinel2_Istanbul/20250917T085431_20250917T085648_T35TPF.tif
# Reading Sentinel file: data/raw/Sentinel2_Istanbul/20251104T085151_20251104T085328_T35TPF.tif
# Reading Landsat file: data/raw/Landsat8_Istanbul/LC08_180032_20170607.tif
# Reading Landsat file: data/raw/Landsat8_Istanbul/LC08_180032_20181101.tif
# Reading Landsat file: data/raw/Landsat8_Istanbul/LC08_180031_20190528.tif
# Reading Landsat file: data/raw/Landsat8_Istanbul/LC08_180032_20190917.tif
# Reading Landsat file: data/raw/Landsat8_Istanbul/LC08_180032_20191206.tif
# Reading Landsat file: data/raw/Landsat8_Istanbul/LC08_180032_20200412.tif
# Reading Landsat file: data/raw/Landsat8_Istanbul/LC08_180032_20200701.tif
# Reading Landsat file: data/raw/Landsat8_Istanbul/LC08_180031_20200802.tif
# Reading Landsat file: data/raw/Landsat8_Istanbul/LC08_180031_20210226.tif
# Reading Landsat file: data/raw/Landsat8_Istanbul/LC08_180032_20210517.tif
# Reading Landsat file: data/raw/Landsat8_Istanbul/LC08_180031_20210805.tif
# Reading Landsat file: data/raw/Landsat8_Istanbul/LC08_180032_20220402.tif
# Reading Landsat file: data/raw/Landsat8_Istanbul/LC08_180031_20220723.tif
# Reading Landsat file: data/raw/Landsat8_Istanbul/LC08_180032_20220909.tif
# Reading Landsat file: data/raw/Landsat8_Istanbul/LC08_180032_20221230.tif
# Reading Landsat file: data/raw/Landsat8_Istanbul/LC08_180031_20230726.tif
# Reading Landsat file: data/raw/Landsat8_Istanbul/LC08_180031_20231014.tif
# Reading Landsat file: data/raw/Landsat8_Istanbul/LC08_180031_20240610.tif
# Reading Landsat file: data/raw/Landsat8_Istanbul/LC08_180032_20240829.tif
# Reading Landsat file: data/raw/Landsat8_Istanbul/LC08_180031_20241219.tif
# Reading Landsat file: data/raw/Landsat8_Istanbul/LC08_180032_20250309.tif
# Reading Landsat file: data/raw/Landsat8_Istanbul/LC08_180031_20250410.tif
# Reading Landsat file: data/raw/Landsat8_Istanbul/LC08_180031_20250528.tif
# Reading Landsat file: data/raw/Landsat8_Istanbul/LC08_180031_20250715.tif
# Reading Landsat file: data/raw/Landsat8_Istanbul/LC08_180032_20250816.tif
# Reading Landsat file: data/raw/Landsat8_Istanbul/LC08_180032_20250917.tif
# Reading Landsat file: data/raw/Landsat8_Istanbul/LC08_180032_20251104.tif
# Reading MODIS file: data/raw/MODIS_Istanbul/2017_06_07.tif
# Reading MODIS file: data/raw/MODIS_Istanbul/2018_11_01.tif
# Reading MODIS file: data/raw/MODIS_Istanbul/2019_05_28.tif
# Reading MODIS file: data/raw/MODIS_Istanbul/2019_09_17.tif
# Reading MODIS file: data/raw/MODIS_Istanbul/2019_12_06.tif
# Reading MODIS file: data/raw/MODIS_Istanbul/2020_04_12.tif
# Reading MODIS file: data/raw/MODIS_Istanbul/2020_07_01.tif
# Reading MODIS file: data/raw/MODIS_Istanbul/2020_08_02.tif
# Reading MODIS file: data/raw/MODIS_Istanbul/2021_02_26.tif
# Reading MODIS file: data/raw/MODIS_Istanbul/2021_05_17.tif
# Reading MODIS file: data/raw/MODIS_Istanbul/2021_08_05.tif
# Reading MODIS file: data/raw/MODIS_Istanbul/2022_04_02.tif
# Reading MODIS file: data/raw/MODIS_Istanbul/2022_07_23.tif
# Reading MODIS file: data/raw/MODIS_Istanbul/2022_09_09.tif
# Reading MODIS file: data/raw/MODIS_Istanbul/2022_12_30.tif
# Reading MODIS file: data/raw/MODIS_Istanbul/2023_07_26.tif
# Reading MODIS file: data/raw/MODIS_Istanbul/2023_10_14.tif
# Reading MODIS file: data/raw/MODIS_Istanbul/2024_06_10.tif
# Reading MODIS file: data/raw/MODIS_Istanbul/2024_08_29.tif
# Reading MODIS file: data/raw/MODIS_Istanbul/2024_12_19.tif
# Reading MODIS file: data/raw/MODIS_Istanbul/2025_03_09.tif
# Reading MODIS file: data/raw/MODIS_Istanbul/2025_04_10.tif
# Reading MODIS file: data/raw/MODIS_Istanbul/2025_05_28.tif
# Reading MODIS file: data/raw/MODIS_Istanbul/2025_07_15.tif
# Reading MODIS file: data/raw/MODIS_Istanbul/2025_08_16.tif
# Reading MODIS file: data/raw/MODIS_Istanbul/2025_09_17.tif
# Reading MODIS file: data/raw/MODIS_Istanbul/2025_11_04.tif

# %% [markdown]
# ## Step 02 : Spatial Interpolation

# %%
# Initialize the data processor
data_processor = DataProcessor()

# Get target resolution dimensions from Sentinel-2 (highest resolution: 10 m)
height, width = sentinel2_images[0][0][0].shape

# (Optional) Get original Landsat resolution (30 m)
height2, width2 = landsat_images[0][0][0].shape

# --- Interpolation for Terra MODIS Images ---
# Apply progressive focal mean to fill missing values, then upscale to Sentinel-2 resolution
start_time = time.time()
modis_preprocessed = data_processor.progressive_focal_mean(modis_images)
modis_images_interpolated = data_processor.resize_modis_images(modis_preprocessed, height, width)
end_time = time.time()
print(f"Terra MODIS interpolation took {end_time - start_time:.2f} seconds.")


# --- Interpolation for Landsat Images ---
# Apply multiband progressive focal mean 
start_time = time.time()

landsat_proprocessed = data_processor.progressive_focal_mean_multiband(
    landsat_images, initial_size=5, step_size=5
)

end_time = time.time()
print(f"Landsat 8 interpolation took {end_time - start_time:.2f} seconds.")

# --- Interpolation for Sentinel-2 Images ---
# Sentinel-2 is already high resolution
start_time = time.time()

sentinel2_proprocessed = data_processor.progressive_focal_mean_multiband(
    sentinel2_images, initial_size=15, step_size=15
)

end_time = time.time()
print(f"Sentinel 2 interpolation took {end_time - start_time:.2f} seconds.")
# Out:
# Image number :  1  has been filled
# Image number :  2  has been filled
# Image number :  3  has been filled
# Image number :  4  has been filled
# Image number :  5  has been filled
# Image number :  6  has been filled
# Image number :  7  has been filled
# Image number :  8  has been filled
# Image number :  9  has been filled
# Image number :  10  has been filled
# Image number :  11  has been filled
# Image number :  12  has been filled
# Image number :  13  has been filled
# Image number :  14  has been filled
# Image number :  15  has been filled
# Image number :  16  has been filled
# Image number :  17  has been filled
# Image number :  18  has been filled
# Image number :  19  has been filled
# Image number :  20  has been filled
# Image number :  21  has been filled
# Image number :  22  has been filled
# Image number :  23  has been filled
# Image number :  24  has been filled
# Image number :  25  has been filled
# Image number :  26  has been filled
# Image number :  27  has been filled
# Terra MODIS interpolation took 0.13 seconds.
# Image number: 1 has been filled
# Image number: 2 has been filled
# Image number: 3 has been filled
# Image number: 4 has been filled
# Image number: 5 has been filled
# Image number: 6 has been filled
# Image number: 7 has been filled
# Image number: 8 has been filled
# Image number: 9 has been filled
# Image number: 10 has been filled
# Image number: 11 has been filled
# Image number: 12 has been filled
# Image number: 13 has been filled
# Image number: 14 has been filled
# Image number: 15 has been filled
# Image number: 16 has been filled
# Image number: 17 has been filled
# Image number: 18 has been filled
# Image number: 19 has been filled
# Image number: 20 has been filled
# Image number: 21 has been filled
# Image number: 22 has been filled
# Image number: 23 has been filled
# Image number: 24 has been filled
# Image number: 25 has been filled
# Image number: 26 has been filled
# Image number: 27 has been filled
# Landsat 8 interpolation took 162.00 seconds.
# Image number: 1 has been filled
# Image number: 2 has been filled
# Image number: 3 has been filled
# Image number: 4 has been filled
# Image number: 5 has been filled
# Image number: 6 has been filled
# Image number: 7 has been filled
# Image number: 8 has been filled
# Image number: 9 has been filled
# Image number: 10 has been filled
# Image number: 11 has been filled
# Image number: 12 has been filled
# Image number: 13 has been filled
# Image number: 14 has been filled
# Image number: 15 has been filled
# Image number: 16 has been filled
# Image number: 17 has been filled
# Image number: 18 has been filled
# Image number: 19 has been filled
# Image number: 20 has been filled
# Image number: 21 has been filled
# Image number: 22 has been filled
# Image number: 23 has been filled
# Image number: 24 has been filled
# Image number: 25 has been filled
# Image number: 26 has been filled
# Image number: 27 has been filled
# Sentinel 2 interpolation took 1542.65 seconds.

# %% [markdown]
# ## Step 03 : Save the Triples

# %%
import os
from datetime import datetime

# Parse the dates from string to datetime objects
dates = [datetime.strptime(date, "%Y-%m-%d") for date in common_dates_array]

# Define output folder for the triple dataset
out_dir = "data/Triple/MODIS_Landsat8_Sentinel2"
os.makedirs(out_dir, exist_ok=True)  # Create the folder if it doesn't exist

# Save the preprocessed Terra MODIS, Landsat 8, and Sentinel-2 images
get_triple.save_modis_formatted(modis_images_interpolated, dates, out_dir)
get_triple.save_landsat_formatted(landsat_proprocessed, dates, out_dir)
get_triple.save_sentinel_formatted(sentinel2_proprocessed, dates, out_dir)
