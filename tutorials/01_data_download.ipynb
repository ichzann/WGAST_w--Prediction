# %% [markdown]
# # Tutorial 01: Downloading Satellite Data from Google Earth Engine
#
# In this tutorial, we will download and prepare Earth Observation data from three different satellite platforms using Google Earth Engine (GEE) and our custom Python processors:
#
# - Sentinel-2 : NDVI, NDWI, NDBI (10–20 m, 5-day revisit).
# - Landsat 8 : LST, NDVI, NDWI, NDBI (30 m, 16-day).
# - Terra MODIS : LST (1 km, daily).
#
# After retrieving the data, we will:
# - Filter images based on pixel quality and availability.
# - Extract only the relevant spectral indices or temperature bands.
# - Find the spatio-temporal intersection between the three satellite datasets.
# - Save the matched results for further processing and training of WGAST.

# %%
import sys
import os
sys.path.append(os.path.abspath('..'))  # go up to root directory

from data_download.Sentinel2Processor import Sentinel2Processor
from data_download.Landsat8Processor import Landsat8Processor
from data_download.MODISProcessor import MODISProcessor
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Step 01 : Define Region of Interest and Time Range
# The ROI and the start/end dates below are those used in the WGAST study. For other applications or locations, you should update these values accordingly.

# %%
#roi = [1.8352731328559473, 47.844911277451844, 1.99343366332974, 47.95130583226066]# -> Orlens, France
roi = [28.963878734763104, 40.99138522259559, 29.122039265236896, 41.09777977740441] # istanbul
#roi = [31.156619734763103, 29.991202722595592, 31.314780265236896, 30.09759727740441] # Cairo
#roi=[-3.7828802652368965, 40.36360272259559, -3.6247197347631035, 40.46999727740441] # Madrid
#roi = [12.413119734763104, 41.83700272259559, 12.571280265236896, 41.94339727740441] # Rome



city = "Istanbul"
start_date = '2017-03-28'
end_date = '2026-04-01'
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Step 02: Download and Preprocess Satellite Data from GEE

# %%
# Define pixel availability threshold
# Only images with at least this percentage of valid (non-cloudy / non-missing) pixels will be kept
pixel_threshold = 80

# ------------------------------
# ✅ Sentinel-2
# ------------------------------

# Initialize processor
Sentinel_SR_preprocess = Sentinel2Processor(
    start_date=start_date,
    end_date=end_date,
    bounds=roi
)

# Load image collection
Sentinel2_data = Sentinel_SR_preprocess.get_Sentinel2_collection()
print('Sentinel-2 images before filtering:', Sentinel_SR_preprocess.countImages(Sentinel2_data))

# Filter by pixel availability
Sentinel2_data_filtered = Sentinel_SR_preprocess.filter_disponible_images(Sentinel2_data, pixel_threshold)
print('Sentinel-2 images after filtering:', Sentinel_SR_preprocess.countImages(Sentinel2_data_filtered))

# Extract NDVI, NDBI, NDWI
Sentinel2_data_filtered_SR = Sentinel_SR_preprocess.get_index(Sentinel2_data_filtered)

# Get timestamps
dates_sentinel2 = Sentinel_SR_preprocess.get_times(Sentinel2_data_filtered_SR)


# ------------------------------
# ✅ Landsat 8 
# ------------------------------

# Initialize processor
Landsat_LST_preprocess = Landsat8Processor(
    start_date=start_date,
    end_date=end_date,
    bounds=roi
)

# Load image collection
L8_data = Landsat_LST_preprocess.get_Landsat_collection()
print('Landsat 8 images before filtering:', Landsat_LST_preprocess.countImages(L8_data))

# Filter by pixel availability
L8_data_filtered = Landsat_LST_preprocess.filter_disponible_images(L8_data, pixel_threshold)
print('Landsat 8 images after filtering:', Landsat_LST_preprocess.countImages(L8_data_filtered))

# Extract LST, NDVI, NDBI, NDWI
L8_LST_index_data_filtered = Landsat_LST_preprocess.get_LST_index(L8_data_filtered)

# Get timestamps
L8_times_filtered = Landsat_LST_preprocess.get_times(L8_LST_index_data_filtered)


# ------------------------------
# ✅ MODIS 
# ------------------------------

# Initialize processor
MODIS_LST_preprocess = MODISProcessor(
    start_date=start_date,
    end_date=end_date,
    bounds=roi
)

# Load image collection
MODIS_data = MODIS_LST_preprocess.get_MODIS_collection()
print('MODIS images before filtering:', MODIS_LST_preprocess.countImages(MODIS_data))

# Filter by pixel availability
MODIS_data_filtered = MODIS_LST_preprocess.filter_disponible_images(MODIS_data, pixel_threshold)
print('MODIS images after filtering:', MODIS_LST_preprocess.countImages(MODIS_data_filtered))

# Extract LST band
MODIS_LST_data = MODIS_LST_preprocess.get_LST(MODIS_data_filtered)

# Get formatted timestamps
MODIS_times = MODIS_LST_preprocess.get_formatted_times(MODIS_data_filtered)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Sentinel-2 images before filtering: 1333
# Sentinel-2 images after filtering: 447
# Landsat 8 images before filtering: 332
# Landsat 8 images after filtering: 167
# MODIS images before filtering: 3279
# MODIS images after filtering: 1090

# %% [markdown]
# ##  Step 03: Find Common Acquisition Dates Across Sentinel-2, Landsat 8, and Terra MODIS

# %%
import numpy as np

# Extract date-only strings (YYYY-MM-DD) from each satellite time list
dates_modis = np.array([date.split(' ')[0] for date in MODIS_times])
dates_landsat = np.array([date.split('T')[0] for date in L8_times_filtered])
dates_sentinel = np.array([date.split('T')[0] for date in dates_sentinel2])

# Find the intersection across all three satellites
common_dates = np.intersect1d(dates_sentinel, dates_landsat)
common_dates = np.intersect1d(common_dates, dates_modis)

# Save the result for reproducibility
np.save(f'common_dates_t1_{city}.npy', common_dates)
print(f"Total common dates found: {len(common_dates)}")

# Filter each dataset to keep only the common dates
MODIS_LST_data_common = MODIS_LST_preprocess.filter_by_common_dates(MODIS_LST_data, common_dates)
Landsat_LST_data_common = MODIS_LST_preprocess.filter_by_common_dates(L8_LST_index_data_filtered, common_dates)
Sentinel2_SR_data_common = MODIS_LST_preprocess.filter_by_common_dates(Sentinel2_data_filtered_SR, common_dates)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Total common dates found: 27

# %% [markdown]
# ## Step 04: Export Common-Date Satellite Images

# %%
import os
import geemap

# ----------------- Export MODIS -----------------
modis_dir = f'data/wgast/raw/MODIS_{city}'
if not os.path.exists(modis_dir):
    os.makedirs(modis_dir)

geemap.ee_export_image_collection(
    MODIS_LST_data_common,
    out_dir=modis_dir,
    scale=1000,  # MODIS resolution: 1km
    region=MODIS_LST_preprocess.aoi
)


# ----------------- Export Landsat 8 -----------------
landsat_dir = f'data/wgast/raw/Landsat8_{city}'
if not os.path.exists(landsat_dir):
    os.makedirs(landsat_dir)

geemap.ee_export_image_collection(
    Landsat_LST_data_common,
    out_dir=landsat_dir,
    scale=30,  # Landsat 8resolution: 30m
    region=Landsat_LST_preprocess.aoi
)



# ----------------- Export Sentinel-2 -----------------
# 👉 If the size of Sentinel-2 images is small, prefer Option 1 (local export).
# 👉 If the size is too large, use Option 2 (Google Drive) to avoid memory or disk issues.

# ✅ Option 1: Export to local disk (recommended if image size is small)
sentinel_dir = f'data/wgast/raw/Sentinel2_{city}'
if not os.path.exists(sentinel_dir):
    os.makedirs(sentinel_dir)

geemap.ee_export_image_collection(
    Sentinel2_SR_data_common,
    out_dir=sentinel_dir,
    scale=10,  # Sentinel-2 resolution: 10m
    region=Sentinel_SR_preprocess.aoi
)

# ❌ Option 2: Export to Google Drive (uncomment below if local export is too heavy)
# geemap.ee_export_image_collection_to_drive(
#     Sentinel2_SR_data_common,
#     folder='export_sentinel_Indexs',
#     scale=10,
#     region=Sentinel_SR_preprocess.aoi,
#     maxPixels=1e13  # Increase limit for large export
# )
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#
tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/e185ed694c5289afbd2fa611bda5d218-669fe6ff6e4c668832cf3a58427ac3c7:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Landsat8_Istanbul/LC08_180031_20250528.tif
#
#
# Exporting 24/54: data/raw/Landsat8_Istanbul/LC08_180031_20250715.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/161c423470c01eaebc1a262009bb5ad4-89a7bbe5be857bafb98a343ba586c034:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Landsat8_Istanbul/LC08_180031_20250715.tif
#
#
# Exporting 25/54: data/raw/Landsat8_Istanbul/LC08_180031_20250816.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/85adb6e8ee4ff96e4df30914a5855bb5-0dc85359c08cf76753e7fa4dbde194f4:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Landsat8_Istanbul/LC08_180031_20250816.tif
#
#
# Exporting 26/54: data/raw/Landsat8_Istanbul/LC08_180031_20250917.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/1a975640ddda22ac5f65ed5e10befea7-04318655ae1f6867815d49a9d7f72abd:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Landsat8_Istanbul/LC08_180031_20250917.tif
#
#
# Exporting 27/54: data/raw/Landsat8_Istanbul/LC08_180031_20251104.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/42445d0c112745d6ea197bfc389da80f-8bc4e2af553fe6bae69d45d678a3c28e:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Landsat8_Istanbul/LC08_180031_20251104.tif
#
#
# Exporting 28/54: data/raw/Landsat8_Istanbul/LC08_180032_20170607.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/3712156ef59adf2cad968dc8833f47c2-b2eb36400effd02bfc93b7189d041cd8:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Landsat8_Istanbul/LC08_180032_20170607.tif
#
#
# Exporting 29/54: data/raw/Landsat8_Istanbul/LC08_180032_20181101.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/b6141c1e2081870483e476f50ccac8fc-94fc21c3b76d23f19cb2b93ad493c08d:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Landsat8_Istanbul/LC08_180032_20181101.tif
#
#
# Exporting 30/54: data/raw/Landsat8_Istanbul/LC08_180032_20190528.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/02068e936457a50953f0554b1e5941b6-9e5c9a8083640390223ad2eeece51430:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Landsat8_Istanbul/LC08_180032_20190528.tif
#
#
# Exporting 31/54: data/raw/Landsat8_Istanbul/LC08_180032_20190917.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/0854b6476a780a683f8cd289cdc1177d-da9c446bad89a454bd3819c1f03ae2cc:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Landsat8_Istanbul/LC08_180032_20190917.tif
#
#
# Exporting 32/54: data/raw/Landsat8_Istanbul/LC08_180032_20191206.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/7e0e6dfbb5e328d678ed208fbe21aad8-bade1a3d509d4d05f3ad45b582e8e641:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Landsat8_Istanbul/LC08_180032_20191206.tif
#
#
# Exporting 33/54: data/raw/Landsat8_Istanbul/LC08_180032_20200412.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/cb767169c8e41f9071a896f456e06534-984e8d23c6947890a77c3af33dce484e:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Landsat8_Istanbul/LC08_180032_20200412.tif
#
#
# Exporting 34/54: data/raw/Landsat8_Istanbul/LC08_180032_20200701.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/3fcbb210f7709de47aa6ec3f05777d60-2c50fe21785f72eb415501e10abeb6f4:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Landsat8_Istanbul/LC08_180032_20200701.tif
#
#
# Exporting 35/54: data/raw/Landsat8_Istanbul/LC08_180032_20200802.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/3b8750c988abc5fe2ef0bd81dbbe93b0-7d836123785fe883dd35e6e6a079cfa9:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Landsat8_Istanbul/LC08_180032_20200802.tif
#
#
# Exporting 36/54: data/raw/Landsat8_Istanbul/LC08_180032_20210226.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/e45347eab14e2fd1dd3eb87220b71c54-a9d4d127cd9b2c3a1b2236ff67615094:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Landsat8_Istanbul/LC08_180032_20210226.tif
#
#
# Exporting 37/54: data/raw/Landsat8_Istanbul/LC08_180032_20210517.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/52de21de48b06c7039f0e971a8439676-478aeb8629c1f90a94bb071240e55a3a:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Landsat8_Istanbul/LC08_180032_20210517.tif
#
#
# Exporting 38/54: data/raw/Landsat8_Istanbul/LC08_180032_20210805.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/51e6cd79d55567d1b20195a211658726-d762ff0f5512da43b3a07a3b00c1e2c0:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Landsat8_Istanbul/LC08_180032_20210805.tif
#
#
# Exporting 39/54: data/raw/Landsat8_Istanbul/LC08_180032_20220402.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/829af4664b7d4239e0b4f466421dbb86-5ab4714c31f0b75d451231aa949279e5:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Landsat8_Istanbul/LC08_180032_20220402.tif
#
#
# Exporting 40/54: data/raw/Landsat8_Istanbul/LC08_180032_20220723.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/1ad5e5e0b9ec1fc06bd2957e2029bfc7-caec06e4fe2841dc5b7da94e1777b8bf:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Landsat8_Istanbul/LC08_180032_20220723.tif
#
#
# Exporting 41/54: data/raw/Landsat8_Istanbul/LC08_180032_20220909.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/d3f72d55bf902cb4295be4bc792c0e6a-14bbc6cfcb6b7ad5e8da24cbb0f46303:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Landsat8_Istanbul/LC08_180032_20220909.tif
#
#
# Exporting 42/54: data/raw/Landsat8_Istanbul/LC08_180032_20221230.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/c09af7db8b1e43e45a5371aa2c44c57c-c1bbb9dc64ed5bc982991f6b21130f8b:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Landsat8_Istanbul/LC08_180032_20221230.tif
#
#
# Exporting 43/54: data/raw/Landsat8_Istanbul/LC08_180032_20230726.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/431adefa7eb416145340a2396ffc4112-dbc4a73d1d7439b2ad9fd5a791c038db:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Landsat8_Istanbul/LC08_180032_20230726.tif
#
#
# Exporting 44/54: data/raw/Landsat8_Istanbul/LC08_180032_20231014.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/e911121522d31e7be966e7c0dc0f2067-db0039ea879ac0e4bf55549ec7754ab6:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Landsat8_Istanbul/LC08_180032_20231014.tif
#
#
# Exporting 45/54: data/raw/Landsat8_Istanbul/LC08_180032_20240610.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/9cefabdcbe797b515bbdcf7ceca2fdda-860ef107c5e6db4e6b4b8ab57bb6821b:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Landsat8_Istanbul/LC08_180032_20240610.tif
#
#
# Exporting 46/54: data/raw/Landsat8_Istanbul/LC08_180032_20240829.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/60ab63518a362c0363fef4cb91339f2a-1dd19a2e802aca15a52ffe454cee3f46:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Landsat8_Istanbul/LC08_180032_20240829.tif
#
#
# Exporting 47/54: data/raw/Landsat8_Istanbul/LC08_180032_20241219.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/aa51c22a421f291cdedb16fb283c4660-491ccd177b3161c9b024ceb3b068c251:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Landsat8_Istanbul/LC08_180032_20241219.tif
#
#
# Exporting 48/54: data/raw/Landsat8_Istanbul/LC08_180032_20250309.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/7cc9cb8b0109b6700963889b6c86b8ca-570c07ad55eeb9df91708d717b5305b9:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Landsat8_Istanbul/LC08_180032_20250309.tif
#
#
# Exporting 49/54: data/raw/Landsat8_Istanbul/LC08_180032_20250410.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/326e3fe8dc31f17f22c6e0811dcf60e5-90ee45eed4227ad077c98a8ae944cdef:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Landsat8_Istanbul/LC08_180032_20250410.tif
#
#
# Exporting 50/54: data/raw/Landsat8_Istanbul/LC08_180032_20250528.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/0c1bf4a348fcdcb7e4eab8085b77cda1-43dc85f8045e4a96a5ab995506a55005:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Landsat8_Istanbul/LC08_180032_20250528.tif
#
#
# Exporting 51/54: data/raw/Landsat8_Istanbul/LC08_180032_20250715.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/9bde27e8a1c2adadb9a5603e06dfd28b-d4452deca653aaf48ff8aced35bd2e61:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Landsat8_Istanbul/LC08_180032_20250715.tif
#
#
# Exporting 52/54: data/raw/Landsat8_Istanbul/LC08_180032_20250816.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/bf0597fb319cf19597fcea98dcd990fd-889683a8e22ef1f185081b35df0ee74b:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Landsat8_Istanbul/LC08_180032_20250816.tif
#
#
# Exporting 53/54: data/raw/Landsat8_Istanbul/LC08_180032_20250917.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/107dd2d32f3ea0baad7da86ffb80fa22-23960e5de0a2012bb58b6f4f2ac420b4:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Landsat8_Istanbul/LC08_180032_20250917.tif
#
#
# Exporting 54/54: data/raw/Landsat8_Istanbul/LC08_180032_20251104.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/b178a1e34310ebcb79e21509af35dc83-1ac07f83cdab3a19e3129da444d29532:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Landsat8_Istanbul/LC08_180032_20251104.tif
#
#
# Total number of images: 28
#
# Exporting 1/28: data/raw/Sentinel2_Istanbul/20170607T090019_20170607T090017_T35TPF.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/b4d43b5806b83ec98b904c4c0a5048a6-7dc9a90b97a66320dbaab889fc0f832e:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Sentinel2_Istanbul/