# %% [markdown]
# # Tutorial 01: Downloading Satellite Data from Google Earth Engine
#
# In this tutorial, we will download and prepare Earth Observation data from three different satellite platforms using Google Earth Engine (GEE) and our custom Python processors:
#
# - Sentinel-2 : NDVI, NDWI, NDBI (10–20 m, 5-day revisit).
# - Landsat 8 : LST, NDVI, NDWI, NDBI (30 m, 16-day).
# - Terra MODIS : LST (1 km, daily).
#
# After retrieving the data, we will:
# - Filter images based on pixel quality and availability.
# - Extract only the relevant spectral indices or temperature bands.
# - Find the spatio-temporal intersection between the three satellite datasets.
# - Save the matched results for further processing and training of WGAST.

# %%
import sys
import os
sys.path.append(os.path.abspath('..'))  # go up to root directory

from data_download.Sentinel2Processor import Sentinel2Processor
from data_download.Landsat8Processor import Landsat8Processor
from data_download.MODISProcessor import MODISProcessor
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Step 01 : Define Region of Interest and Time Range
# The ROI and the start/end dates below are those used in the WGAST study. For other applications or locations, you should update these values accordingly.

# %%
from cities import CITIES  

city = "Orleans"          
roi  = CITIES[city]["roi"] 

start_date = '2017-10-01'
end_date = '2024-12-31'
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Step 02: Download and Preprocess Satellite Data from GEE

# %%
# Define pixel availability threshold
# Only images with at least this percentage of valid (non-cloudy / non-missing) pixels will be kept
pixel_threshold = 80

# ------------------------------
# ✅ Sentinel-2
# ------------------------------

# Initialize processor
Sentinel_SR_preprocess = Sentinel2Processor(
    start_date=start_date,
    end_date=end_date,
    bounds=roi
)

# Load image collection
Sentinel2_data = Sentinel_SR_preprocess.get_Sentinel2_collection()
print('Sentinel-2 images before filtering:', Sentinel_SR_preprocess.countImages(Sentinel2_data))

# Filter by pixel availability
Sentinel2_data_filtered = Sentinel_SR_preprocess.filter_disponible_images(Sentinel2_data, pixel_threshold)
print('Sentinel-2 images after filtering:', Sentinel_SR_preprocess.countImages(Sentinel2_data_filtered))

# Extract NDVI, NDBI, NDWI
Sentinel2_data_filtered_SR = Sentinel_SR_preprocess.get_index(Sentinel2_data_filtered)

# Get timestamps
dates_sentinel2 = Sentinel_SR_preprocess.get_times(Sentinel2_data_filtered_SR)


# ------------------------------
# ✅ Landsat 8 
# ------------------------------

# Initialize processor
Landsat_LST_preprocess = Landsat8Processor(
    start_date=start_date,
    end_date=end_date,
    bounds=roi
)

# Load image collection
L8_data = Landsat_LST_preprocess.get_Landsat_collection()
print('Landsat 8 images before filtering:', Landsat_LST_preprocess.countImages(L8_data))

# Filter by pixel availability
L8_data_filtered = Landsat_LST_preprocess.filter_disponible_images(L8_data, pixel_threshold)
print('Landsat 8 images after filtering:', Landsat_LST_preprocess.countImages(L8_data_filtered))

# Extract LST, NDVI, NDBI, NDWI
L8_LST_index_data_filtered = Landsat_LST_preprocess.get_LST_index(L8_data_filtered)

# Get timestamps
L8_times_filtered = Landsat_LST_preprocess.get_times(L8_LST_index_data_filtered)


# ------------------------------
# ✅ MODIS 
# ------------------------------

# Initialize processor
MODIS_LST_preprocess = MODISProcessor(
    start_date=start_date,
    end_date=end_date,
    bounds=roi
)

# Load image collection
MODIS_data = MODIS_LST_preprocess.get_MODIS_collection()
print('MODIS images before filtering:', MODIS_LST_preprocess.countImages(MODIS_data))

# Filter by pixel availability
MODIS_data_filtered = MODIS_LST_preprocess.filter_disponible_images(MODIS_data, pixel_threshold)
print('MODIS images after filtering:', MODIS_LST_preprocess.countImages(MODIS_data_filtered))

# Extract LST band
MODIS_LST_data = MODIS_LST_preprocess.get_LST(MODIS_data_filtered)

# Get formatted timestamps
MODIS_times = MODIS_LST_preprocess.get_formatted_times(MODIS_data_filtered)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Sentinel-2 images before filtering: 2080
# Sentinel-2 images after filtering: 260
# Landsat 8 images before filtering: 113
# Landsat 8 images after filtering: 46
# MODIS images before filtering: 2636
# MODIS images after filtering: 760

# %% [markdown]
# ##  Step 03: Find Common Acquisition Dates Across Sentinel-2, Landsat 8, and Terra MODIS

# %%
import numpy as np

# Extract date-only strings (YYYY-MM-DD) from each satellite time list
dates_modis = np.array([date.split(' ')[0] for date in MODIS_times])
dates_landsat = np.array([date.split('T')[0] for date in L8_times_filtered])
dates_sentinel = np.array([date.split('T')[0] for date in dates_sentinel2])

# Find the intersection across all three satellites
common_dates = np.intersect1d(dates_sentinel, dates_landsat)
common_dates = np.intersect1d(common_dates, dates_modis)

# Save the result for reproducibility
np.save(f'common_dates_t2_{city}.npy', common_dates)
print(f"Total common dates found: {len(common_dates)}")

# Filter each dataset to keep only the common dates
MODIS_LST_data_common = MODIS_LST_preprocess.filter_by_common_dates(MODIS_LST_data, common_dates)
Landsat_LST_data_common = MODIS_LST_preprocess.filter_by_common_dates(L8_LST_index_data_filtered, common_dates)
Sentinel2_SR_data_common = MODIS_LST_preprocess.filter_by_common_dates(Sentinel2_data_filtered_SR, common_dates)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Total common dates found: 10

# %% [markdown]
# ## Step 04: Export Common-Date Satellite Images

# %%
import os
import geemap

# ----------------- Export MODIS -----------------
# crs="EPSG:4326": GEE's native MODIS export is Sinusoidal and the written
# GeoTIFF gets tagged with the WGS84 ELLIPSOID instead of the MODIS authalic
# SPHERE (R=6371007.181 m). That bad tag shifts the raster ~18 km north of the
# Landsat/Sentinel AOI, so any later reproject onto the Landsat grid finds no
# overlap and produces all-zeros. Forcing a clean CRS at export avoids it.
modis_dir = f'data/wgast/raw/MODIS_{city}'
if not os.path.exists(modis_dir):
    os.makedirs(modis_dir)

geemap.ee_export_image_collection(
    MODIS_LST_data_common,
    out_dir=modis_dir,
    scale=1000,  # MODIS resolution: 1km
    region=MODIS_LST_preprocess.aoi,
    crs="EPSG:4326",
)


# ----------------- Export Landsat 8 -----------------
landsat_dir = f'data/wgast/raw/Landsat8_{city}'
if not os.path.exists(landsat_dir):
    os.makedirs(landsat_dir)

geemap.ee_export_image_collection(
    Landsat_LST_data_common,
    out_dir=landsat_dir,
    scale=30,  # Landsat 8resolution: 30m
    region=Landsat_LST_preprocess.aoi
)



# ----------------- Export Sentinel-2 -----------------
# 👉 If the size of Sentinel-2 images is small, prefer Option 1 (local export).
# 👉 If the size is too large, use Option 2 (Google Drive) to avoid memory or disk issues.

# ✅ Option 1: Export to local disk (recommended if image size is small)
sentinel_dir = f'data/wgast/raw/Sentinel2_{city}'
if not os.path.exists(sentinel_dir):
    os.makedirs(sentinel_dir)

geemap.ee_export_image_collection(
    Sentinel2_SR_data_common,
    out_dir=sentinel_dir,
    scale=10,  # Sentinel-2 resolution: 10m
    region=Sentinel_SR_preprocess.aoi
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Total number of images: 10
#
# Exporting 1/10: data/wgast/raw/MODIS_Orleans/2018_02_23.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/8de2c8dd6737f3c1414b6311934629ab-fd13a8a303101bdf8d6bff20bf20a830:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/wgast/raw/MODIS_Orleans/2018_02_23.tif
#
#
# Exporting 2/10: data/wgast/raw/MODIS_Orleans/2018_10_21.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/915b1fd52e5d30f05bf1440d4a6f6d60-bff39130d4cf5c571d0e522c0529ecd6:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/wgast/raw/MODIS_Orleans/2018_10_21.tif
#
#
# Exporting 3/10: data/wgast/raw/MODIS_Orleans/2019_09_06.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/4d324e1d40c9aadae2a1abdcb512239c-8f686e1eb4e7ee7483bd93f87c19cef6:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/wgast/raw/MODIS_Orleans/2019_09_06.tif
#
#
# Exporting 4/10: data/wgast/raw/MODIS_Orleans/2020_07_22.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/6f1b357583570787f2f688638c91aa9c-7ed23c31ed30ccb7f4268fb007bc1dcb:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/wgast/raw/MODIS_Orleans/2020_07_22.tif
#
#
# Exporting 5/10: data/wgast/raw/MODIS_Orleans/2022_03_06.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/8e35910040c350295f324871e0e43f73-c7727eeac7ac5a3f4c55f4a0a19e9c80:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/wgast/raw/MODIS_Orleans/2022_03_06.tif
#
#
# Exporting 6/10: data/wgast/raw/MODIS_Orleans/2022_08_13.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/4e8fb0b1d62bb21d5a495833f816c521-417dad6a7a295f01a18cda2d8a0cdb88:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/wgast/raw/MODIS_Orleans/2022_08_13.tif
#
#
# Exporting 7/10: data/wgast/raw/MODIS_Orleans/2023_05_28.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/75951853165f4f04514bcd57cb073231-1945c4e99d5df08d0d51884e4303ccfd:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/wgast/raw/MODIS_Orleans/2023_05_28.tif
#
#
# Exporting 8/10: data/wgast/raw/MODIS_Orleans/2024_04_12.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/a28223a0d45955e5412dcb364d4ea545-b909c0712ffcb56f8d17996545c39e76:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/wgast/raw/MODIS_Orleans/2024_04_12.tif
#
#
# Exporting 9/10: data/wgast/raw/MODIS_Orleans/2024_09_19.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/9e1d1257a6c8c84b557a14733c3f9898-daf5b6a218cba1b1f0a1bb129ea47dc9:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/wgast/raw/MODIS_Orleans/2024_09_19.tif
#
#
# Exporting 10/10: data/wgast/raw/MODIS_Orleans/2024_10_21.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/803265a106c8c8891d88436ac1898181-3ea36370725f43cc8227a1b8631a9420:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/wgast/raw/MODIS_Orleans/2024_10_21.tif
#
#
# Total number of images: 10
#
# Exporting 1/10: data/wgast/raw/Landsat8_Orleans/LC08_199027_20180223.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/34f9f3bfbc3c746fe4e7a130df918f1c-d4ed34d0581fc47255262839e6ad2a99:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/wgast/raw/Landsat8_Orleans/LC08_199027_20180223.tif
#
#
# Exporting 2/10: data/wgast/raw/Landsat8_Orleans/LC08_199027_20181021.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/956f1d9db04bd8152d8d6d65a2d6bdae-bdc1c1e36d89283bfce6513b8293b1dc:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/wgast/raw/Landsat8_Orleans/LC08_199027_20181021.tif
#
#
# Exporting 3/10: data/wgast/raw/Landsat8_Orleans/LC08_199027_20190906.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/4325b70c7b1389c7e04ff0be6d129519-9da01869316242f74738d74279018f47:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/wgast/raw/Landsat8_Orleans/LC08_199027_20190906.tif
#
#
# Exporting 4/10: data/wgast/raw/Landsat8_Orleans/LC08_199027_20200722.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/a07b8a750cdb1bbbb20dec2619cf1ace-a78b9ca086edf752d91e4ba66625b259:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/wgast/raw/Landsat8_Orleans/LC08_199027_20200722.tif
#
#
# Exporting 5/10: data/wgast/raw/Landsat8_Orleans/LC08_199027_20220306.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/ea397e0157b4ddac647672fa2204efc2-62adda84e06364ec6e371902450cacdc:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/wgast/raw/Landsat8_Orleans/LC08_199027_20220306.tif
#
#
# Exporting 6/10: data/wgast/raw/Landsat8_Orleans/LC08_199027_20220813.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/53eaa1164d06a4505beddb58f4f4f187-85b5dfa42609a9807f4924aff4f06ada:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/wgast/raw/Landsat8_Orleans/LC08_199027_20220813.tif
#
#
# Exporting 7/10: data/wgast/raw/Landsat8_Orleans/LC08_199027_20230528.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/0c966410b14f0a532fd767408eb69752-524189d5790f4a536eae362648df9ffc:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/wgast/raw/Landsat8_Orleans/LC08_199027_20230528.tif
#
#
# Exporting 8/10: data/wgast/raw/Landsat8_Orleans/LC08_199027_20240412.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/8e576f780eb1e0fc1459ece867b2dadb-881357e9a5855cf8a034943bd3369ca9:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/wgast/raw/Landsat8_Orleans/LC08_199027_20240412.tif
#
#
# Exporting 9/10: data/wgast/raw/Landsat8_Orleans/LC08_199027_20240919.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/1f192b049af35305e6f76d2a44e53e96-3f463cc9664ff8c132a360d14dfd5ef8:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/wgast/raw/Landsat8_Orleans/LC08_199027_20240919.tif
#
#
# Exporting 10/10: data/wgast/raw/Landsat8_Orleans/LC08_199027_20241021.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/dab6e2aed75167a2e468ade263f4cd62-7dacaf17e5bb3c0873c06b52a29ee498:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/wgast/raw/Landsat8_Orleans/LC08_199027_20241021.tif
#
#
# Total number of images: 10
#
# Exporting 1/10: data/wgast/raw/Sentinel2_Orleans/20180223T110041_20180223T110631_T31UDP.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/39a19d91cd2f5b3d91efff8363d41df4-ab1effd81bde91c0c425f62838053a5c:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/wgast/raw/Sentinel2_Orleans/20180223T110041_20180223T110631_T31UDP.tif
#
#
# Exporting 2/10: data/wgast/raw/Sentinel2_Orleans/20181021T110101_20181021T110649_T31UDP.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/2350f782a3a0980c1ab5a5f07d7ce6d5-a9a84f2542d1c20917a252e05edfbe6a:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/wgast/raw/Sentinel2_Orleans/20181021T110101_20181021T110649_T31UDP.tif
#
#
# Exporting 3/10: data/wgast/raw/Sentinel2_Orleans/20190906T105621_20190906T110527_T31UDP.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/a5b3821b318c79a94a9bf6ee94ea8fb9-650ff578ae8f0ee033088cb2fa1cabbf:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/wgast/raw/Sentinel2_Orleans/20190906T105621_20190906T110527_T31UDP.tif
#
#
# Exporting 4/10: data/wgast/raw/Sentinel2_Orleans/20200722T105631_20200722T110027_T31UDP.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/f38261c6b60750c7cafb15d2acf5538d-ff28ee41094613025274af020f1ecb46:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/wgast/raw/Sentinel2_Orleans/20200722T105631_20200722T110027_T31UDP.tif
#
#
# Exporting 5/10: data/wgast/raw/Sentinel2_Orleans/20220306T104819_20220306T105455_T31UDP.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/f8826103fd7c6e6496d7995691244c29-feb1e8b783a2dc965e480648f2e9f70f:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/wgast/raw/Sentinel2_Orleans/20220306T104819_20220306T105455_T31UDP.tif
#
#
# Exporting 6/10: data/wgast/raw/Sentinel2_Orleans/20220813T104629_20220813T104623_T31UDP.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/31ae273ee799bf5a8b5a53020e17e33b-3ae81cf5a39d2a6f31b849d552149343:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/wgast/raw/Sentinel2_Orleans/20220813T104629_20220813T104623_T31UDP.tif
#
#
# Exporting 7/10: data/wgast/raw/Sentinel2_Orleans/20230528T105621_20230528T105909_T31UDP.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/de0b8d6964731300e4778d230abf0269-9a1191f03355962f854d4ae19fe7adb6:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/wgast/raw/Sentinel2_Orleans/20230528T105621_20230528T105909_T31UDP.tif
#
#
# Exporting 8/10: data/wgast/raw/Sentinel2_Orleans/20240412T105621_20240412T110532_T31UDP.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/a124405db83490fa23ba6e3c45f95c8a-5b9129c240c0cb0a9c0e0946556b4146:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/wgast/raw/Sentinel2_Orleans/20240412T105621_20240412T110532_T31UDP.tif
#
#
# Exporting 9/10: data/wgast/raw/Sentinel2_Orleans/20240919T105731_20240919T110558_T31UDP.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/71c930e245e8420a973ba472b641f8f1-3c84e308058849fad9c897a6cddabed0:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/wgast/raw/Sentinel2_Orleans/20240919T105731_20240919T110558_T31UDP.tif
#
#
# Exporting 10/10: data/wgast/raw/Sentinel2_Orleans/20241021T105009_20241021T105637_T31UDP.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/71e9cf6c5268317d14c1e8ad02f07b42-08262f8fd04afc8f763ae98d49c0ae36:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/wgast/raw/Sentinel2_Orleans/20241021T105009_20241021T105637_T31UDP.tif
