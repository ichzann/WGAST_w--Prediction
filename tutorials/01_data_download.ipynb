# %% [markdown]
# # Tutorial 01: Downloading Satellite Data from Google Earth Engine
#
# In this tutorial, we will download and prepare Earth Observation data from three different satellite platforms using Google Earth Engine (GEE) and our custom Python processors:
#
# - Sentinel-2 : NDVI, NDWI, NDBI (10–20 m, 5-day revisit).
# - Landsat 8 : LST, NDVI, NDWI, NDBI (30 m, 16-day).
# - Terra MODIS : LST (1 km, daily).
#
# After retrieving the data, we will:
# - Filter images based on pixel quality and availability.
# - Extract only the relevant spectral indices or temperature bands.
# - Find the spatio-temporal intersection between the three satellite datasets.
# - Save the matched results for further processing and training of WGAST.

# %%
import sys
import os
sys.path.append(os.path.abspath('..'))  # go up to root directory

from data_download.Sentinel2Processor import Sentinel2Processor
from data_download.Landsat8Processor import Landsat8Processor
from data_download.MODISProcessor import MODISProcessor
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Step 01 : Define Region of Interest and Time Range
# The ROI and the start/end dates below are those used in the WGAST study. For other applications or locations, you should update these values accordingly.

# %%
roi = [1.8352731328559473, 47.844911277451844, 1.99343366332974, 47.95130583226066]# -> Orlens, France
#roi = [28.889319734763104, 40.99000272259559, 29.047480265236896, 41.09639727740441] # istanbul
#roi = [31.156619734763103, 29.991202722595592, 31.314780265236896, 30.09759727740441] # Cairo
#roi=[-3.7828802652368965, 40.36360272259559, -3.6247197347631035, 40.46999727740441] # Madrid
#roi = [12.413119734763104, 41.83700272259559, 12.571280265236896, 41.94339727740441] # Rome



city = "France"
start_date = '2017-03-28'
end_date = '2026-04-01'
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Step 02: Download and Preprocess Satellite Data from GEE

# %%
# Define pixel availability threshold
# Only images with at least this percentage of valid (non-cloudy / non-missing) pixels will be kept
pixel_threshold = 80

# ------------------------------
# ✅ Sentinel-2
# ------------------------------

# Initialize processor
Sentinel_SR_preprocess = Sentinel2Processor(
    start_date=start_date,
    end_date=end_date,
    bounds=roi
)

# Load image collection
Sentinel2_data = Sentinel_SR_preprocess.get_Sentinel2_collection()
print('Sentinel-2 images before filtering:', Sentinel_SR_preprocess.countImages(Sentinel2_data))

# Filter by pixel availability
Sentinel2_data_filtered = Sentinel_SR_preprocess.filter_disponible_images(Sentinel2_data, pixel_threshold)
print('Sentinel-2 images after filtering:', Sentinel_SR_preprocess.countImages(Sentinel2_data_filtered))

# Extract NDVI, NDBI, NDWI
Sentinel2_data_filtered_SR = Sentinel_SR_preprocess.get_index(Sentinel2_data_filtered)

# Get timestamps
dates_sentinel2 = Sentinel_SR_preprocess.get_times(Sentinel2_data_filtered_SR)


# ------------------------------
# ✅ Landsat 8 
# ------------------------------

# Initialize processor
Landsat_LST_preprocess = Landsat8Processor(
    start_date=start_date,
    end_date=end_date,
    bounds=roi
)

# Load image collection
L8_data = Landsat_LST_preprocess.get_Landsat_collection()
print('Landsat 8 images before filtering:', Landsat_LST_preprocess.countImages(L8_data))

# Filter by pixel availability
L8_data_filtered = Landsat_LST_preprocess.filter_disponible_images(L8_data, pixel_threshold)
print('Landsat 8 images after filtering:', Landsat_LST_preprocess.countImages(L8_data_filtered))

# Extract LST, NDVI, NDBI, NDWI
L8_LST_index_data_filtered = Landsat_LST_preprocess.get_LST_index(L8_data_filtered)

# Get timestamps
L8_times_filtered = Landsat_LST_preprocess.get_times(L8_LST_index_data_filtered)


# ------------------------------
# ✅ MODIS 
# ------------------------------

# Initialize processor
MODIS_LST_preprocess = MODISProcessor(
    start_date=start_date,
    end_date=end_date,
    bounds=roi
)

# Load image collection
MODIS_data = MODIS_LST_preprocess.get_MODIS_collection()
print('MODIS images before filtering:', MODIS_LST_preprocess.countImages(MODIS_data))

# Filter by pixel availability
MODIS_data_filtered = MODIS_LST_preprocess.filter_disponible_images(MODIS_data, pixel_threshold)
print('MODIS images after filtering:', MODIS_LST_preprocess.countImages(MODIS_data_filtered))

# Extract LST band
MODIS_LST_data = MODIS_LST_preprocess.get_LST(MODIS_data_filtered)

# Get formatted timestamps
MODIS_times = MODIS_LST_preprocess.get_formatted_times(MODIS_data_filtered)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Sentinel-2 images before filtering: 2632
# Sentinel-2 images after filtering: 331
# Landsat 8 images before filtering: 138
# Landsat 8 images after filtering: 57
# MODIS images before filtering: 3279
# MODIS images after filtering: 969

# %% [markdown]
# ##  Step 03: Find Common Acquisition Dates Across Sentinel-2, Landsat 8, and Terra MODIS

# %%
import numpy as np

# Extract date-only strings (YYYY-MM-DD) from each satellite time list
dates_modis = np.array([date.split(' ')[0] for date in MODIS_times])
dates_landsat = np.array([date.split('T')[0] for date in L8_times_filtered])
dates_sentinel = np.array([date.split('T')[0] for date in dates_sentinel2])

# Find the intersection across all three satellites
common_dates = np.intersect1d(dates_sentinel, dates_landsat)
common_dates = np.intersect1d(common_dates, dates_modis)

# Save the result for reproducibility
np.save('common_dates_t1.npy', common_dates)
print(f"Total common dates found: {len(common_dates)}")

# Filter each dataset to keep only the common dates
MODIS_LST_data_common = MODIS_LST_preprocess.filter_by_common_dates(MODIS_LST_data, common_dates)
Landsat_LST_data_common = MODIS_LST_preprocess.filter_by_common_dates(L8_LST_index_data_filtered, common_dates)
Sentinel2_SR_data_common = MODIS_LST_preprocess.filter_by_common_dates(Sentinel2_data_filtered_SR, common_dates)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Total common dates found: 14

# %% [markdown]
# ## Step 04: Export Common-Date Satellite Images

# %%
import os
import geemap

# ----------------- Export MODIS -----------------
modis_dir = f'data/raw/MODIS_{city}'
if not os.path.exists(modis_dir):
    os.makedirs(modis_dir)

geemap.ee_export_image_collection(
    MODIS_LST_data_common,
    out_dir=modis_dir,
    scale=1000,  # MODIS resolution: 1km
    region=MODIS_LST_preprocess.aoi
)


# ----------------- Export Landsat 8 -----------------
landsat_dir = f'data/raw/Landsat8_{city}'
if not os.path.exists(landsat_dir):
    os.makedirs(landsat_dir)

geemap.ee_export_image_collection(
    Landsat_LST_data_common,
    out_dir=landsat_dir,
    scale=30,  # Landsat 8resolution: 30m
    region=Landsat_LST_preprocess.aoi
)



# ----------------- Export Sentinel-2 -----------------
# 👉 If the size of Sentinel-2 images is small, prefer Option 1 (local export).
# 👉 If the size is too large, use Option 2 (Google Drive) to avoid memory or disk issues.

# ✅ Option 1: Export to local disk (recommended if image size is small)
sentinel_dir = f'data/raw/Sentinel2_{city}'
if not os.path.exists(sentinel_dir):
    os.makedirs(sentinel_dir)

geemap.ee_export_image_collection(
    Sentinel2_SR_data_common,
    out_dir=sentinel_dir,
    scale=10,  # Sentinel-2 resolution: 10m
    region=Sentinel_SR_preprocess.aoi
)

# ❌ Option 2: Export to Google Drive (uncomment below if local export is too heavy)
# geemap.ee_export_image_collection_to_drive(
#     Sentinel2_SR_data_common,
#     folder='export_sentinel_Indexs',
#     scale=10,
#     region=Sentinel_SR_preprocess.aoi,
#     maxPixels=1e13  # Increase limit for large export
# )
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Total number of images: 14
#
# Exporting 1/14: data/raw/MODIS_France/2017_04_09.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/47207c8cb60c241c36e771d619c6bcd9-9c880ec734243f27b40f83aaf66d918f:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/MODIS_France/2017_04_09.tif
#
#
# Exporting 2/14: data/raw/MODIS_France/2018_02_23.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/172caa0da27e3c257cc9b8203ec052c4-aafe2926aea678202ab98637df940aec:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/MODIS_France/2018_02_23.tif
#
#
# Exporting 3/14: data/raw/MODIS_France/2018_10_21.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/d8ce7649187764be0f69dd2e8cc65155-f3056e753eac1c2d1c4ad349b7b40689:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/MODIS_France/2018_10_21.tif
#
#
# Exporting 4/14: data/raw/MODIS_France/2019_09_06.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/7cd47d007d79e298d161ffaa8fc55448-2f80ba542497ae6fb3a0a94daacfcb9c:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/MODIS_France/2019_09_06.tif
#
#
# Exporting 5/14: data/raw/MODIS_France/2020_07_22.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/25f32f6338fcc67d90e6bdb04ae475c9-6f8376b10cacaca38029926f786e7cbe:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/MODIS_France/2020_07_22.tif
#
#
# Exporting 6/14: data/raw/MODIS_France/2022_03_06.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/337c0a586d6ded5a8f87b91de61c3958-e7ce9cc4f7bc089dc5ebae53a4921e56:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/MODIS_France/2022_03_06.tif
#
#
# Exporting 7/14: data/raw/MODIS_France/2022_08_13.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/f4b9458eace47af1070ba8e1d8d64afa-d51d9980bd763e54bc69d6edbb0708d4:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/MODIS_France/2022_08_13.tif
#
#
# Exporting 8/14: data/raw/MODIS_France/2023_05_28.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/d85d9ddf4e2485f2197c2ef856fefd6a-0c99393cebad88094a1cb192d2ae9e6e:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/MODIS_France/2023_05_28.tif
#
#
# Exporting 9/14: data/raw/MODIS_France/2024_04_12.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/365e69e3ae22b78ca16a5187f9e3022c-da6e791ff01293421a3d04a825c68495:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/MODIS_France/2024_04_12.tif
#
#
# Exporting 10/14: data/raw/MODIS_France/2024_09_19.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/62fd058ebfd98b38291f9e0d88a2d3e4-b00f27045ec4e6a49d8d59f2d7f3b9ab:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/MODIS_France/2024_09_19.tif
#
#
# Exporting 11/14: data/raw/MODIS_France/2024_10_21.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/2ed1a0a88ec5284ea70f26a591641923-5040b9679761c134f5cd32e324186864:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/MODIS_France/2024_10_21.tif
#
#
# Exporting 12/14: data/raw/MODIS_France/2025_06_18.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/1040cce958214b82df58a53bd878a06d-387dba32d75b3d2c81bff53c71ff2c0b:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/MODIS_France/2025_06_18.tif
#
#
# Exporting 13/14: data/raw/MODIS_France/2025_08_05.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/1825016cb0eab6aadcf95db77c88e0a4-1db91565d425f626e85947a56ec2a1ac:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/MODIS_France/2025_08_05.tif
#
#
# Exporting 14/14: data/raw/MODIS_France/2025_09_06.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/20cf41f7cb9d957598c8844914995d37-497ea98f4192b6718472577965ab6f17:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/MODIS_France/2025_09_06.tif
#
#
# Total number of images: 14
#
# Exporting 1/14: data/raw/Landsat8_France/LC08_199027_20170409.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/3c2c36b1f51dd1f0c21fa8aca3f0b466-70fd85ff5cd9548a8b942f93af9f5819:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Landsat8_France/LC08_199027_20170409.tif
#
#
# Exporting 2/14: data/raw/Landsat8_France/LC08_199027_20180223.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/037732da0a7154d58ce7d043f6f54c28-4911e0efba8d5bb3d9599afb16c018e7:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Landsat8_France/LC08_199027_20180223.tif
#
#
# Exporting 3/14: data/raw/Landsat8_France/LC08_199027_20181021.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/48c6cce289c5d1ab1bfe06020f563e30-f69cdce9c81f23699351b5789857ee51:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Landsat8_France/LC08_199027_20181021.tif
#
#
# Exporting 4/14: data/raw/Landsat8_France/LC08_199027_20190906.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/26b61f551a218754f5487bf1d30debdd-6136bbd56d76e3abae3e511f54126123:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Landsat8_France/LC08_199027_20190906.tif
#
#
# Exporting 5/14: data/raw/Landsat8_France/LC08_199027_20200722.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/9d1eb662d0666309669402594dfe099f-3456835e4332bb70df40d84fac3eddef:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Landsat8_France/LC08_199027_20200722.tif
#
#
# Exporting 6/14: data/raw/Landsat8_France/LC08_199027_20220306.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/87a5357236e893e034eba555fdc37ef6-f47c055d50a32442e5bfa5fc5394ac1c:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Landsat8_France/LC08_199027_20220306.tif
#
#
# Exporting 7/14: data/raw/Landsat8_France/LC08_199027_20220813.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/1df1613ab34a79eb506dc096db97fd28-8b79c864886a011d2b8a019713edb04d:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Landsat8_France/LC08_199027_20220813.tif
#
#
# Exporting 8/14: data/raw/Landsat8_France/LC08_199027_20230528.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/6c20eedeff880c5907f7fbff820b9fda-a4f9f430ac34bce3f81373c6366d9302:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Landsat8_France/LC08_199027_20230528.tif
#
#
# Exporting 9/14: data/raw/Landsat8_France/LC08_199027_20240412.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/e3f256ca515aeba7cac85536fb3323fd-6a0e5584f86c171ce995d5393bd6ac60:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Landsat8_France/LC08_199027_20240412.tif
#
#
# Exporting 10/14: data/raw/Landsat8_France/LC08_199027_20240919.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/a2978641b614fab81d327999bda8ad9d-0cd98434307060c2ce5088a2471ff26f:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Landsat8_France/LC08_199027_20240919.tif
#
#
# Exporting 11/14: data/raw/Landsat8_France/LC08_199027_20241021.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/3415cdb2b1719df6d58fe03a3f47c527-169e34e0cdf6529e915a4a1f8356e232:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Landsat8_France/LC08_199027_20241021.tif
#
#
# Exporting 12/14: data/raw/Landsat8_France/LC08_199027_20250618.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/49472460afe30d21719ce0ae382ffbe5-cad7dbee9877bba2bf0cc34ac5cd3065:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Landsat8_France/LC08_199027_20250618.tif
#
#
# Exporting 13/14: data/raw/Landsat8_France/LC08_199027_20250805.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/4545bbffb845d1bf63611be1fa59624a-dd61c82efe2738519bf8904e223f6619:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Landsat8_France/LC08_199027_20250805.tif
#
#
# Exporting 14/14: data/raw/Landsat8_France/LC08_199027_20250906.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/10457776abc109e023a81329d21bdd7f-9cc6b2569337d7cf24e18739ca4ae483:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Landsat8_France/LC08_199027_20250906.tif
#
#
# Total number of images: 14
#
# Exporting 1/14: data/raw/Sentinel2_France/20170409T105651_20170409T110529_T31UDP.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/ae9d575821439640bfd6238a26678302-2099f82a4692560a73f754658cc1e714:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Sentinel2_France/20170409T105651_20170409T110529_T31UDP.tif
#
#
# Exporting 2/14: data/raw/Sentinel2_France/20180223T110041_20180223T110631_T31UDP.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/1ed20b1397f4d70897902db15b899382-6e750b48217a7cf9d281c8c9b291dc1f:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Sentinel2_France/20180223T110041_20180223T110631_T31UDP.tif
#
#
# Exporting 3/14: data/raw/Sentinel2_France/20181021T110101_20181021T110649_T31UDP.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/067fab507fb41f778d54ddebc73a11be-e2912e0f9bfa91e45e31426288d7e7f5:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Sentinel2_France/20181021T110101_20181021T110649_T31UDP.tif
#
#
# Exporting 4/14: data/raw/Sentinel2_France/20190906T105621_20190906T110527_T31UDP.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/8f407b362fb64f9f1c1f62932310aed4-35e261ec638eb74e312a2ac4f7cc823b:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Sentinel2_France/20190906T105621_20190906T110527_T31UDP.tif
#
#
# Exporting 5/14: data/raw/Sentinel2_France/20200722T105631_20200722T110027_T31UDP.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/333b44c6bb1df27fdbd7177c1affcd8c-16243abc93bccc19181e9f29172820a0:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Sentinel2_France/20200722T105631_20200722T110027_T31UDP.tif
#
#
# Exporting 6/14: data/raw/Sentinel2_France/20220306T104819_20220306T105455_T31UDP.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/340658966877dfd1127b98631ad95914-df0682ccded567f2c4a3438e4e095ffd:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Sentinel2_France/20220306T104819_20220306T105455_T31UDP.tif
#
#
# Exporting 7/14: data/raw/Sentinel2_France/20220813T104629_20220813T104623_T31UDP.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/53d4372d7fe5112a03a9b93eec109f3e-ce2b82900ef20e8660bd52e9f1d44a4b:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Sentinel2_France/20220813T104629_20220813T104623_T31UDP.tif
#
#
# Exporting 8/14: data/raw/Sentinel2_France/20230528T105621_20230528T105909_T31UDP.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/0cc2a5adf19b5d119f4e66573775bf7d-1b66b7a709310abeb83f1004416a362f:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Sentinel2_France/20230528T105621_20230528T105909_T31UDP.tif
#
#
# Exporting 9/14: data/raw/Sentinel2_France/20240412T105621_20240412T110532_T31UDP.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/9b57d4eaa28431e62a784c0cd5d5a3ea-db67c89c2ad4facd655d865a978d45d3:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Sentinel2_France/20240412T105621_20240412T110532_T31UDP.tif
#
#
# Exporting 10/14: data/raw/Sentinel2_France/20240919T105731_20240919T110558_T31UDP.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/92b62e3c777f88effa7ee37d72fa34ed-2958b6df96aa99eb4acf96b4c4676dc9:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Sentinel2_France/20240919T105731_20240919T110558_T31UDP.tif
#
#
# Exporting 11/14: data/raw/Sentinel2_France/20241021T105009_20241021T105637_T31UDP.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/2ec013d953d6599678321e2275d4393c-083fc3ef267237e0acf1375985e79f15:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Sentinel2_France/20241021T105009_20241021T105637_T31UDP.tif
#
#
# Exporting 12/14: data/raw/Sentinel2_France/20250618T105651_20250618T110342_T31UDP.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/d39cfce060de2949ce6c750dbb9e3c9a-4ef2f055f02b5c69527d6cd2a2b40732:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Sentinel2_France/20250618T105651_20250618T110342_T31UDP.tif
#
#
# Exporting 13/14: data/raw/Sentinel2_France/20250805T105641_20250805T105914_T31UDP.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/eb4ee0064bad9b6cb7c7fded84fb5070-bdcec8da81e818f8740c7e071928aaf1:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Sentinel2_France/20250805T105641_20250805T105914_T31UDP.tif
#
#
# Exporting 14/14: data/raw/Sentinel2_France/20250906T104619_20250906T104933_T31UDP.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/flawless-spirit-495715-b4/thumbnails/07acda82dff09d8d71d645c2f08e934f-7777c7ceae5a450e6dd4a8581a00cd93:getPixels
# Please wait ...
# Data downloaded to /Users/ihsanbolum/WGAST_w--Prediction/tutorials/data/raw/Sentinel2_France/20250906T104619_20250906T104933_T31UDP.tif
